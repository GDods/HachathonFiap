# %%
import pandas as pd

# %%
df_func = pd.read_excel(r'BD\Dados Vivante Funcionários.xls', sheet_name='DADOS FUNCIONAIS')
df_func.head()
# Out:
#    MATRÍCULA            EMPRESA                               FILIAL  \
# 0      10438  Vivante S/A [001]             ACCOR PAULISTA [0003_DB]
# 1      10515  Vivante S/A [001]         Vivante S.A. (São Paulo) [2]
# 2      10479  Vivante S/A [001]  Vivante S.A. (São Paulo Matriz) [1]
# 3      10393  Vivante S/A [001]         Vivante S.A. (São Paulo) [2]
# 4      11879  Vivante S/A [001]  Vivante S.A. (São Paulo Matriz) [1]
#
#             CNPJ                                 ENDEREÇO FUNCIONAL  \
# 0  2386450000270  AVENIDA NAÇÕES UNIDAS - 8º ANDAR, 7815 - PINHE...
# 1  2386450000270  RUA NORMA PIERUCCINI GIANNOTTI, 327 - BARRA FUNDA
# 2  2386450000190  Rua Alexandre Dumas, 2200 - Chacara Santo Antonio
# 3  2386450000270  RUA NORMA PIERUCCINI GIANNOTTI, 327 - BARRA FUNDA
# 4  2386450000190  RUA NORMA PIERUCCINI GIANNOTTI, 327 - BARRA FUNDA
#
#      LOCALIDADE                   CENTRO DE CUSTO CENTRO DE RESPONSABILIDADE  \
# ...

# %%
df_func.to_excel(r'BD Tratado\df_func.xlsx', index=False)

# %%
df_pessoais = pd.read_excel(r'BD\Dados Vivante Funcionários.xls', sheet_name='DADOS PESSOAIS')
df_pessoais.head()
# Out:
#    MATRÍCULA       SEXO DATA DE NASCIMENTO MÊS DE ANIVERSÁRIO  \
# 0      10438   FEMININO         1961-06-20          Junho
# 1      10515  MASCULINO         1950-03-18          Março
# 2      10479  MASCULINO         1971-01-08          Janeiro
# 3      10393  MASCULINO         1955-04-18          Abril
# 4      11879  MASCULINO         1962-09-24          Setembro
#
#   MÊS DE ANIVERSÁRIO ADMISSÃO NACIONALIDADE CIDADE DE NASCIMENTO  \
# 0                   Março        Brasileiro            Sao Paulo
# 1                   Novembro     Brasileiro       Rio de Janeiro
# 2                   Setembro     Brasileiro            Sao Paulo
# 3                   Abril        Brasileiro           Rio Grande
# 4                   Março        Brasileiro       Belo Horizonte
#
#   UF DE NASCIMENTO ESTADO CIVIL  \
# 0             SP       Solteiro
# 1             RJ         Casado
# 2             SP     Desquitado
# 3             RS     Divorciado
# 4             MG         Casado
#
# ...

# %%
df_pessoais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5463 entries, 0 to 5462
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   MATRÍCULA                    5463 non-null   int64
#  1   SEXO                         5463 non-null   object
#  2   DATA DE NASCIMENTO           5463 non-null   datetime64[ns]
#  3   MÊS DE ANIVERSÁRIO           5463 non-null   object
#  4   MÊS DE ANIVERSÁRIO ADMISSÃO  5463 non-null   object
#  5   NACIONALIDADE                5463 non-null   object
#  6   CIDADE DE NASCIMENTO         5399 non-null   object
#  7   UF DE NASCIMENTO             5396 non-null   object
#  8   ESTADO CIVIL                 5463 non-null   object
#  9   GRAU DE INSTRUÇÃO            5463 non-null   object
#  10  ENDEREÇO                     5463 non-null   object
#  11  BAIRRO                       5456 non-null   object
# ...

# %%
df_dependentes = pd.read_excel(r'BD\Dados Vivante Funcionários.xls', sheet_name='DEPENDENTES')
df_dependentes.head()
# Out:
#    MATRÍCULA  CÓD. DEPENDENTE DATA DE NASCIMENTO       SEXO PARENTESCO  \
# 0     205827            66306         1910-01-01  MASCULINO        Pai
# 1     205827            66307         1910-01-01   FEMININO        Mãe
# 2      90293            46363         1996-02-19   FEMININO   Filho(a)
# 3      90293           103290         1954-03-23  MASCULINO     Marido
# 4     200400            48113         1994-11-02   FEMININO   Filho(a)
#
#   DEP. SALÁRIO FAMÍLIA DEP. IRRF LIMITE DEP. IRRF
# 0                  Não       Não              NaT
# 1                  Não       Não              NaT
# 2                  Sim       Sim       2017-02-01
# 3                  Sim       Não              NaT
# 4                  Sim       Sim       2015-11-01

# %%
df_hist_horario = pd.read_excel(r'BD\Dados Vivante Funcionários.xls', sheet_name='HISTÓRICO DE HORÁRIO')
df_hist_horario.head()
# Out:
#    MATRÍCULA                                            HORÁRIO CÓD. HORÁRIO  \
# 0     205827      12:40-21:00 (6 x 1)  Ref. 16:00-17:00 - Móvel   A12401720
# 1     205827    13:40-22:00 -  (6 X 1) Ref. 17:00-18:00 - Móvel   A13401720
# 2     205827                      12:40-21:00 - Escala 6x1 Fixo   R12401720
# 3     205827                    07:00 - 15:20 - Escala 6x1 Fixo   R07001720
# 4     205827  08:00 às 16:20 - Conforme Escala ( 6 / 1 ) - M...   A08001720
#
#   INÍCIO DE VALIDADE HORÁRIO ATUAL
# 0         2012-09-16           Sim
# 1         2012-08-16           NaN
# 2         2012-07-28           NaN
# 3         2012-02-07           NaN
# 4         2012-01-16           NaN

# %%
df_transporte = pd.read_excel(r'BD\Dados Vivante Funcionários.xls', sheet_name='TRANSPORTE')
df_transporte.head()
# Out:
#    MATRÍCULA            TRANSPORTE INÍCIO VALIDADE  NÚM. VIAGENS DIA  \
# 0     205827    SPTRANS METRO 4.83      2011-06-01                 2
# 1     205827        CMT   BOM 3.20      2011-06-01                 2
# 2      90293          ATM TEU 4.80      2012-02-01                 2
# 3      90293              ATP 4.20      2011-06-01                 2
# 4     200400  SPTRANS INTEGRA 9.24      2012-09-06                 2
#
#    VALOR POR VIAGEM
# 0              4.83
# 1              3.20
# 2              4.80
# 3              4.20
# 4              9.24

# %%
df_beneficio_funcionario = pd.read_excel(r'BD\Dados Vivante Funcionários.xls', sheet_name='BENEFÍCIOS FUNCIONÁRIO')
df_beneficio_funcionario.head()
# Out:
#    MATRÍCULA            TIPO BENEFÍCIO  \
# 0      90293        Assistência Médica
# 1      90293  Assistência Odontológica
# 2     200400        Assistência Médica
# 3     200570        Assistência Médica
# 4     200570  Assistência Odontológica
#
#                                FORNECEDOR            PLANO DATA DE INCLUSÃO
# 0  DOCTOR CLIN OP DE PLANOS DE SAUDE LTDA  FLEX SAUDE HOSP       2006-12-12
# 1                             Interodonto   TOP PREMIUM DO       2020-03-01
# 2        INTERMEDICA SISTEMA DE SAUDE S/A        MAX I 200       1998-10-18
# 3        INTERMEDICA SISTEMA DE SAUDE S/A        MAX I 200       2002-09-17
# 4                             Interodonto   TOP PREMIUM DO       2020-03-01

# %%
df_beneficio_dependente = pd.read_excel(r'BD\Dados Vivante Funcionários.xls', sheet_name='BENEFÍCIOS DEPENDENTES')
df_beneficio_dependente.head()
# Out:
#    MATRÍCULA  CÓD. DEPENDENTE            TIPO BENEFÍCIO  \
# 0      90293            46363        Assistência Médica
# 1      90293            46363  Assistência Odontológica
# 2     200400            48114        Assistência Médica
# 3     200400            48115        Assistência Médica
# 4     200570            48702  Assistência Odontológica
#
#                                FORNECEDOR            PLANO DATA DE INCLUSÃO
# 0  DOCTOR CLIN OP DE PLANOS DE SAUDE LTDA  FLEX SAUDE HOSP       2006-12-12
# 1                             Interodonto   TOP PREMIUM DO       2020-03-01
# 2        INTERMEDICA SISTEMA DE SAUDE S/A        MAX I 200       1998-10-18
# 3        INTERMEDICA SISTEMA DE SAUDE S/A        MAX I 200       1998-10-18
# 4                       SulAmerica Odonto        Básico 20       2017-01-11
